# %% [markdown]
# <a href="https://colab.research.google.com/github/vtk251zhdo/-/blob/LAB_1/%D0%9B%D0%90%D0%91%D0%9E%D0%A0%D0%90%D0%A2%D0%9E%D0%A0%D0%9D%D0%90_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Завдання 3

# %%
#Імпорт бібліотек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Зчитування файлу csv
df = pd.read_csv('Automobile.csv')
df.head()
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %% [markdown]
# Завдання 4

# %%
#Фільтр ==

filtered_eq = df[df['name'] == 'ford torino']
filtered_eq.head()
# Out:
#           name   mpg  cylinders  displacement  horsepower  weight  \
# 4  ford torino  17.0          8         302.0       140.0    3449
#
#    acceleration  model_year origin
# 4          10.5          70    usa

# %% [markdown]
# Завдання 5

# %%
#Фільтр !=

filtered_neq = df[df['horsepower'] != 150.0]
filtered_neq.head()
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 4                ford torino  17.0          8         302.0       140.0
# 5           ford galaxie 500  15.0          8         429.0       198.0
# 6           chevrolet impala  14.0          8         454.0       220.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 4    3449          10.5          70    usa
# 5    4341          10.0          70    usa
# 6    4354           9.0          70    usa

# %% [markdown]
# Завдання 6

# %%
#Фільтр isin

filtered_isin = df[df['displacement'].isin([307.0, 350.0, 302.0])]
filtered_isin.head()
# Out:
#                          name   mpg  cylinders  displacement  horsepower  \
# 0   chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1           buick skylark 320  15.0          8         350.0       165.0
# 4                 ford torino  17.0          8         302.0       140.0
# 26                  chevy c20  10.0          8         307.0       200.0
# 38           chevrolet impala  14.0          8         350.0       165.0
#
#     weight  acceleration  model_year origin
# 0     3504          12.0          70    usa
# 1     3693          11.5          70    usa
# 4     3449          10.5          70    usa
# 26    4376          15.0          70    usa
# 38    4209          12.0          71    usa

# %% [markdown]
# Завдання 7

# %%
#Фільтр <=, >=

filtered_le = df[df['horsepower'] <= 120]

filtered_ge = df[df['horsepower'] >= 150]

filtered_range = df[(df['horsepower'] >= 100) & (df['horsepower'] <= 200)]

filtered_le.head()
filtered_ge.head()

filtered_range.head()
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %% [markdown]
# Завдання 8

# %%
#DataFrame з окремими колонками

new_df = df[['name', 'horsepower', 'weight']]
new_df.head()

new_df.to_csv('save.csv', index=False)
# Out:
#                         name  horsepower  weight
# 0  chevrolet chevelle malibu       130.0    3504
# 1          buick skylark 320       165.0    3693
# 2         plymouth satellite       150.0    3436
# 3              amc rebel sst       150.0    3433
# 4                ford torino       140.0    3449

# %% [markdown]
# Завдання 9

# %%
#Генерація випадкових колонок

random_df = pd.DataFrame({
    'id': np.random.uniform(0, 100, 100),
    'range': np.random.uniform(-50, 50, 100),
    'score': np.random.uniform(1000, 5000, 100)
})

random_df.head()

random_df.to_csv('save2.csv', index=False)
# Out:
#           id      range        score
# 0  79.260873  44.794919  1555.012470
# 1  20.957595 -27.495543  3845.593506
# 2  32.869434  10.395572  2024.170902
# 3  46.494557  -7.960831  4497.061608
# 4  97.273549   2.482056  1267.333959

# %% [markdown]
# Завдання 10

# %%
#Лінійний графік з CSV

plt.figure(figsize=(10,5))
plt.plot(df['name'])
plt.title('name')
plt.show()

# %% [markdown]
# Завдання 11

# %%
#Лінійний графік з фільтрами

plt.figure(figsize=(10,5))
plt.plot(filtered_range['name'])
plt.title('name')
plt.show()

# %% [markdown]
# Завдання 12

# %%
#3D Scatter Plot

from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(
    df['displacement'],
    df['horsepower'],
    df['model_year']
)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %% [markdown]
# Завдання 13

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# !pip install tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

alarms = pd.read_csv('/alarms.csv')

#Розділення данних на X | Y
X = alarms.drop('sound', axis=1)
y = alarms['distance']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

model = Sequential([
    Dense(16, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=16
)

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(
    alarms.iloc[:,0],
    alarms.iloc[:,1],
    alarms.iloc[:,2],
    c=alarms['alarm']
)



loss, accuracy = model.evaluate(X_test, y_test)

alarms.head()
plt.show()
print("Accuracy:", accuracy)
# Out:
# ...
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: 0.7361
# Epoch 2/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.6085
# Epoch 3/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5508
# Epoch 4/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5417
# Epoch 5/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.5368
# Epoch 6/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5327
# Epoch 7/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.5294
# Epoch 8/20
# ...
